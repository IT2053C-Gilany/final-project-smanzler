# %% [markdown]
# # Project Title - Edit Me

# %% [markdown]
# ## Data set selection
#
# > In this section, you will need to provide the following information about the selected data set:
# >
# > - Link: https://www.kaggle.com/datasets/dylanmonfret/rlcs-202122
# > - Fields:
#
# games_by_players:
#
# game_id color team_id team_region player_id player_tag core_shots core_goals core_saves core_assists core_score core_shooting_percentage boost_bpm boost_bcpm boost_avg_amount boost_amount_collected boost_amount_stolen boost_amount_collected_big boost_amount_stolen_big boost_amount_collected_small boost_amount_stolen_small boost_count_collected_big boost_count_stolen_big boost_count_collected_small boost_count_stolen_small boost_amount_overfill boost_amount_overfill_stolen boost_amount_used_while_supersonic boost_time_zero_boost boost_percent_zero_boost boost_time_full_boost boost_percent_full_boost boost_time_boost_0_25 boost_time_boost_25_50 boost_time_boost_50_75 boost_time_boost_75_100 boost_percent_boost_0_25 boost_percent_boost_25_50 boost_percent_boost_50_75 boost_percent_boost_75_100 movement_avg_speed movement_total_distance movement_time_supersonic_speed movement_time_boost_speed movement_time_slow_speed movement_time_ground movement_time_low_air movement_time_high_air movement_time_powerslide movement_count_powerslide movement_avg_powerslide_duration movement_avg_speed_percentage movement_percent_slow_speed movement_percent_boost_speed movement_percent_supersonic_speed movement_percent_ground movement_percent_low_air movement_percent_high_air positioning_avg_distance_to_ball positioning_avg_distance_to_ball_possession positioning_avg_distance_to_ball_no_possession positioning_avg_distance_to_mates positioning_time_defensive_third positioning_time_neutral_third positioning_time_offensive_third positioning_time_defensive_half positioning_time_offensive_half positioning_time_behind_ball positioning_time_in_front_ball positioning_time_most_back positioning_time_most_forward positioning_goals_against_while_last_defender positioning_time_closest_to_ball positioning_time_farthest_from_ball positioning_percent_defensive_third positioning_percent_offensive_third positioning_percent_neutral_third positioning_percent_defensive_half positioning_percent_offensive_half positioning_percent_behind_ball positioning_percent_in_front_ball positioning_percent_most_back positioning_percent_most_forward positioning_percent_closest_to_ball positioning_percent_farthest_from_ball demo_inflicted demo_taken advanced_goal_participation advanced_rating advanced_mvp winner platform platform_id car_id car_name steering_sensitivity camera_fov camera_height camera_pitch camera_distance camera_stiffness camera_swivel_speed camera_transition_speed
#
# games_by_teams:
#
# game_id color team_id team_slug team_name team_region ball_possession_time ball_time_in_side core_shots core_goals core_saves core_assists core_score core_shooting_percentage boost_bpm boost_bcpm boost_avg_amount boost_amount_collected boost_amount_stolen boost_amount_collected_big boost_amount_stolen_big boost_amount_collected_small boost_amount_stolen_small boost_count_collected_big boost_count_stolen_big boost_count_collected_small boost_count_stolen_small boost_amount_overfill boost_amount_overfill_stolen boost_amount_used_while_supersonic boost_time_zero_boost boost_time_full_boost boost_time_boost_0_25 boost_time_boost_25_50 boost_time_boost_50_75 boost_time_boost_75_100 movement_total_distance movement_time_supersonic_speed movement_time_boost_speed movement_time_slow_speed movement_time_ground movement_time_low_air movement_time_high_air movement_time_powerslide movement_count_powerslide positioning_time_defensive_third positioning_time_neutral_third positioning_time_offensive_third positioning_time_defensive_half positioning_time_offensive_half positioning_time_behind_ball positioning_time_in_front_ball demo_inflicted demo_taken winner
#
# main:
#
# event_id event event_split event_region event_slug event_start_date event_end_date event_tier event_phase prize_money stage_step stage stage_start_date stage_end_date stage_is_lan stage_is_qualifier liquipedia_link location_venue location_city location_country match_id match_slug match_number match_round match_date match_format reverse_sweep_attempt reverse_sweep game_id game_number game_date game_duration map_id map_name overtime ballchasing_id
#
# matches_by_players:
#
# match_id team_id team_region player_id player_tag core_shots core_goals core_saves core_assists core_score core_shooting_percentage boost_bpm boost_bcpm boost_avg_amount boost_amount_collected boost_amount_stolen boost_amount_collected_big boost_amount_stolen_big boost_amount_collected_small boost_amount_stolen_small boost_count_collected_big boost_count_stolen_big boost_count_collected_small boost_count_stolen_small boost_amount_overfill boost_amount_overfill_stolen boost_amount_used_while_supersonic boost_time_zero_boost boost_percent_zero_boost boost_time_full_boost boost_percent_full_boost boost_time_boost_0_25 boost_time_boost_25_50 boost_time_boost_50_75 boost_time_boost_75_100 boost_percent_boost_0_25 boost_percent_boost_25_50 boost_percent_boost_50_75 boost_percent_boost_75_100 movement_avg_speed movement_total_distance movement_time_supersonic_speed movement_time_boost_speed movement_time_slow_speed movement_time_ground movement_time_low_air movement_time_high_air movement_time_powerslide movement_count_powerslide movement_avg_powerslide_duration movement_avg_speed_percentage movement_percent_slow_speed movement_percent_boost_speed movement_percent_supersonic_speed movement_percent_ground movement_percent_low_air movement_percent_high_air positioning_avg_distance_to_ball positioning_avg_distance_to_ball_possession positioning_avg_distance_to_ball_no_possession positioning_avg_distance_to_mates positioning_time_defensive_third positioning_time_neutral_third positioning_time_offensive_third positioning_time_defensive_half positioning_time_offensive_half positioning_time_behind_ball positioning_time_in_front_ball positioning_time_most_back positioning_time_most_forward positioning_goals_against_while_last_defender positioning_time_closest_to_ball positioning_time_farthest_from_ball positioning_percent_defensive_third positioning_percent_offensive_third positioning_percent_neutral_third positioning_percent_defensive_half positioning_percent_offensive_half positioning_percent_behind_ball positioning_percent_in_front_ball positioning_percent_most_back positioning_percent_most_forward positioning_percent_closest_to_ball positioning_percent_farthest_from_ball demo_inflicted demo_taken advanced_goal_participation advanced_rating score winner
#
# matches_by_teams:
#
# match_id color team_id team_slug team_name team_region core_shots core_goals core_saves core_assists core_score core_shooting_percentage boost_bpm boost_bcpm boost_avg_amount boost_amount_collected boost_amount_stolen boost_amount_collected_big boost_amount_stolen_big boost_amount_collected_small boost_amount_stolen_small boost_count_collected_big boost_count_stolen_big boost_count_collected_small boost_count_stolen_small boost_amount_overfill boost_amount_overfill_stolen boost_amount_used_while_supersonic boost_time_zero_boost boost_time_full_boost boost_time_boost_0_25 boost_time_boost_25_50 boost_time_boost_50_75 boost_time_boost_75_100 movement_total_distance movement_time_supersonic_speed movement_time_boost_speed movement_time_slow_speed movement_time_ground movement_time_low_air movement_time_high_air movement_time_powerslide movement_count_powerslide positioning_time_defensive_third positioning_time_neutral_third positioning_time_offensive_third positioning_time_defensive_half positioning_time_offensive_half positioning_time_behind_ball positioning_time_in_front_ball demo_inflicted demo_taken score winner
#
# players_db:
#
# player_id player_slug player_tag player_name player_country
#
# > - License: https://creativecommons.org/publicdomain/zero/1.0/
#
# ### Data set selection rationale
#
# > Why did you select this data set?
#
# I chose this dataset because I enjoy watching competitive Rocket League and wanted to see what I could find out from a dataset I could find.
#
# ### Questions to be answered
#
# > Using statistical analysis and visualization, what questions would you like to be able answer about this dataset.
# > This could include questions such as:
# >
# > - What is the relationship between X and Y variables?
# > - What is the distribution of the variables?
# > - What is the relationship between the variables and the target?
# >   You will need to frame these questions in a way to show value to a stakeholder (i.e.why should we know about the relationship between X and Y variables?)
#
# - What factors most strongly influence a team's chances of winning?
#   For example, is boost usage, average speed, or time spent in various field zones correlated with match outcomes? Understanding these can help teams optimize their strategies.
#
# - How do individual player stats (e.g., shots, goals, saves) distribute across the league?
#   Knowing the typical range and distribution of these key performance indicators can help benchmark player performance and set realistic training targets.
#
# - Are there notable differences in play style or performance between regions or teams?
#   Comparing metrics like average boost usage or defensive time by region can highlight competitive advantages and inform transfer or recruitment strategies.
#
# - What player or team characteristics are associated with high goal participation or MVP status?
#   Identifying these characteristics could help in talent scouting or developing players for key roles.
#
# - Is there a relationship between match duration, overtime frequency, and total goals scored or player fatigue indicators?
#   This could provide insights for scheduling and managing player workload.
#
# Answering these questions will add practical value by helping stakeholders understand which in-game behaviors and stats drive successful outcomes and where to focus training or scouting efforts.
#
# ### Visualization ideas
#
# > Provide a few examples of what you plan to visualize to answer the questions you posed in the previous section. In this project, you will be producing 6-8 visualizations. You will also be producing an interactive chart using Plotly.
# > Think about what those visualization could be: what are the variables used in the charts? what insights do you hope to gain from them?
#
# Example Visualizations Planned:
#
# 1.  Distribution of Core Player Stats:
#
#     - Visualization: Histograms or boxplots of shots, goals, and saves per player.
#     - Variables: core_shots, core_goals, core_saves (from matches_by_players).
#     - Insight: Identify typical performance ranges and spot outliers or standout performers.
#
# 2.  Correlation Heatmap of Team Metrics and Winning:
#
#     - Visualization: Correlation matrix heatmap.
#     - Variables: Various team-level stats (e.g., boost_avg_amount, core_shots, movement_avg_speed, positioning_time_offensive_third) plus winner (from matches_by_teams).
#     - Insight: See which features most strongly correlate with winning to help teams focus training efforts.
#
# 3.  Regional Comparison of Play Styles:
#
#     - Visualization: Grouped bar chart comparing average boost usage and time in field zones by region.
#     - Variables: team_region, boost_bpm, movement_time_supersonic_speed, positioning_time_offensive_third (from matches_by_teams).
#     - Insight: Discover stylistic differences between regions that might indicate unique strategies.
#
# 4.  Goal Participation by Player Position and Role:
#
#     - Visualization: Strip plot or violin plot of goal participation versus average positioning.
#     - Variables: advanced_goal_participation, positioning_avg_distance_to_ball, positioning_time_most_forward (from matches_by_players).
#     - Insight: Analyze if certain player roles are more involved in goals.
#
# 5.  Relationship Between Match Duration, Overtime, and Total Goals:
#
#     - Visualization: Scatter plot with regression line.
#     - Variables: match duration, overtime frequency, total goals (aggregated from matches_by_teams).
#     - Insight: Determine if longer or overtime-heavy matches have more goals, which can affect player fatigue.
#
# 6.  Interactive Plotly Dashboard:
#     - Visualization: Interactive filterable chart (e.g., team or player stat comparison across regions or over time).
#     - Variables: User-selectable, but could include goals, assists, saves, or advanced_rating (from matches_by_players and teams, joined with region info).
#     - Insight: Allow stakeholders to explore comparisons tailored to their interests.
#
# These visualizations are designed to extract actionable insights regarding player performance, team strategies, regional trends, and key drivers for match outcomes.

# %%
# 🚀 Importing some libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
main = pd.read_csv("data/main.csv")
players = pd.read_csv("data/players_db.csv")

games_players = pd.read_csv("data/games_by_players.csv")
games_teams = pd.read_csv("data/games_by_teams.csv")

matches_players = pd.read_csv("data/matches_by_players.csv")
matches_teams = pd.read_csv("data/matches_by_teams.csv")
# Out:
# /var/folders/4f/ls3xk_j5185d766zbpn66g1h0000gn/T/ipykernel_53102/244238586.py:4: DtypeWarning: Columns (92) have mixed types. Specify dtype option on import or set low_memory=False.
#   games_players = pd.read_csv("data/games_by_players.csv")
