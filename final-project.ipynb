# %% [markdown]
# # Rocket League Championship Series - (2021-2022)
#
# This project analyzes Rocket League Championship Series (RLCS) 2021-2022 data to explore trends, player performance, and key match statistics

# %% [markdown]
# ## Data set selection
#
# > In this section, you will need to provide the following information about the selected data set:
# >
# > - Link: https://www.kaggle.com/datasets/dylanmonfret/rlcs-202122
#
# # Data Cards
#
# games_by_players:
#
# | Field                                          | Description                                                     | Data Type |
# | ---------------------------------------------- | --------------------------------------------------------------- | --------- |
# | game_id                                        | id of corresponding game                                        | float     |
# | color                                          | color                                                           | float     |
# | team_id                                        | id of corresponding team                                        | float     |
# | team_region                                    | team region                                                     | float     |
# | player_id                                      | id of corresponding player                                      | float     |
# | player_tag                                     | name of player                                                  | float     |
# | core_shots                                     | shots                                                           | int       |
# | core_goals                                     | goals                                                           | int       |
# | core_saves                                     | saves                                                           | int       |
# | core_assists                                   | assists                                                         | int       |
# | core_score                                     | score                                                           | int       |
# | core_shooting_percentage                       | shooting percentage                                             | float     |
# | boost_bpm                                      | boost used per minute                                           | float     |
# | boost_bcpm                                     | boost collected per minute                                      | float     |
# | boost_avg_amount                               | average boost amount in tank                                    | float     |
# | boost_amount_collected                         | total boost collected                                           | float     |
# | boost_amount_stolen                            | total boost stolen from oppenent half                           | float     |
# | boost_amount_collected_big                     | total boost collected from big pads                             | float     |
# | boost_amount_stolen_big                        | total boost collected from big pads stolen from oppenent half   | float     |
# | boost_amount_collected_small                   | total boost collected from small pads                           | float     |
# | boost_amount_stolen_small                      | total boost collected from small pads stolen from oppenent half | float     |
# | boost_count_collected_big                      | count of big pads collected                                     | float     |
# | boost_count_stolen_big                         | count of big pads stolen                                        | float     |
# | boost_count_collected_small                    | count of small pads collected                                   | float     |
# | boost_count_stolen_small                       | count of small pads stolen                                      | float     |
# | boost_amount_overfill                          | overfill boost amount                                           | float     |
# | boost_amount_overfill_stolen                   | stolen overfill boost amount                                    | float     |
# | boost_amount_used_while_supersonic             | total boost amount used while supersonic speed                  | float     |
# | boost_time_zero_boost                          | time zero boost                                                 | float     |
# | boost_percent_zero_boost                       | percent of game with zero boost                                 | float     |
# | boost_time_full_boost                          | time full boost                                                 | float     |
# | boost_percent_full_boost                       | percent of game with full boost                                 | float     |
# | boost_time_boost_0_25                          | time boost 0 - 25                                               | float     |
# | boost_time_boost_25_50                         | time boost 25 - 50                                              | float     |
# | boost_time_boost_50_75                         | time boost 50 - 75                                              | float     |
# | boost_time_boost_75_100                        | time boost 75 - 100                                             | float     |
# | boost_percent_boost_0_25                       | percent of game with boost 0 - 25                               | float     |
# | boost_percent_boost_25_50                      | percent of game with boost 25 - 50                              | float     |
# | boost_percent_boost_50_75                      | percent of game with boost 50 - 75                              | float     |
# | boost_percent_boost_75_100                     | percent of game with boost 75 - 100                             | float     |
# | movement_avg_speed                             | average speed (unreal units)                                    | float     |
# | movement_total_distance                        | total distance                                                  | float     |
# | movement_time_supersonic_speed                 | time supersonic speed                                           | float     |
# | movement_time_boost_speed                      | time boost speed                                                | float     |
# | movement_time_slow_speed                       | time slow speed                                                 | float     |
# | movement_time_ground                           | time on ground                                                  | float     |
# | movement_time_low_air                          | time in low air                                                 | float     |
# | movement_time_high_air                         | time in high air                                                | float     |
# | movement_time_powerslide                       | time powersliding                                               | float     |
# | movement_count_powerslide                      | powerslide count                                                | float     |
# | movement_avg_powerslide_duration               | average powerslide duration                                     | float     |
# | movement_avg_speed_percentage                  | average speed percentage                                        | float     |
# | movement_percent_slow_speed                    | percent of game slow speed                                      | float     |
# | movement_percent_boost_speed                   | percent of game boost speed                                     | float     |
# | movement_percent_supersonic_speed              | percent of game supersonic speed                                | float     |
# | movement_percent_ground                        | percent of game on ground                                       | float     |
# | movement_percent_low_air                       | percent of game in low air                                      | float     |
# | movement_percent_high_air                      | percent of game in high air                                     | float     |
# | positioning_avg_distance_to_ball               | average distance to ball                                        | float     |
# | positioning_avg_distance_to_ball_possession    | average distance to ball with possession                        | float     |
# | positioning_avg_distance_to_ball_no_possession | average distance to ball with no possession                     | float     |
# | positioning_avg_distance_to_mates              | average distance to teammates                                   | float     |
# | positioning_time_defensive_third               | time in defensive third                                         | float     |
# | positioning_time_neutral_third                 | time in neutral third                                           | float     |
# | positioning_time_offensive_third               | time in offensive third                                         | float     |
# | positioning_time_defensive_half                | time in defensive half                                          | float     |
# | positioning_time_offensive_half                | time in offensive half                                          | float     |
# | positioning_time_behind_ball                   | time behind the ball                                            | float     |
# | positioning_time_in_front_ball                 | time in front of the ball                                       | float     |
# | positioning_time_most_back                     | time most back on team                                          | float     |
# | positioning_time_most_forward                  | time most forward on team                                       | float     |
# | positioning_goals_against_while_last_defender  | goals against while last defender                               | float     |
# | positioning_time_closest_to_ball               | time closest to ball                                            | float     |
# | positioning_time_farthest_from_ball            | time farthest from ball                                         | float     |
# | positioning_percent_defensive_third            | percent of game in defansive third                              | float     |
# | positioning_percent_offensive_third            | percent of game in offensive third                              | float     |
# | positioning_percent_neutral_third              | percent of game in neutral third                                | float     |
# | positioning_percent_defensive_half             | percent of game in defensive half                               | float     |
# | positioning_percent_offensive_half             | percent of game in offensive half                               | float     |
# | positioning_percent_behind_ball                | percent of game behind the ball                                 | float     |
# | positioning_percent_in_front_ball              | percent of game in front of the ball                            | float     |
# | positioning_percent_most_back                  | percent of game most back                                       | float     |
# | positioning_percent_most_forward               | percent of game most forward                                    | float     |
# | positioning_percent_closest_to_ball            | percent of game closest to the ball                             | float     |
# | positioning_percent_farthest_from_ball         | percent of game farthest from the ball                          | float     |
# | demo_inflicted                                 | demos inflicted                                                 | float     |
# | demo_taken                                     | demos taken                                                     | float     |
# | advanced_goal_participation                    | goal participation                                              | float     |
# | advanced_rating                                | average rating                                                  | float     |
# | advanced_mvp                                   | was mvp                                                         | bool      |
# | winner                                         | won game                                                        | bool      |
# | platform                                       | platfrom                                                        | float     |
# | platform_id                                    | user id on platform                                             | float     |
# | car_id                                         | id of car                                                       | float     |
# | car_name                                       | name of car                                                     | float     |
# | steering_sensitivity                           | steering sensitivity                                            | float     |
# | camera_fov                                     | field of view                                                   | float     |
# | camera_height                                  | camera height                                                   | float     |
# | camera_pitch                                   | camera pitch                                                    | float     |
# | camera_distance                                | camera distance                                                 | float     |
# | camera_stiffness                               | camera stiffness                                                | float     |
# | camera_swivel_speed                            | camera swivel speed                                             | float     |
# | camera_transition_speed                        | camera transition speed                                         | float     |
#
# games_by_teams:
#
# | Field                              | Description                                                     | Data Type |
# | ---------------------------------- | --------------------------------------------------------------- | --------- |
# | game_id                            | id of corresponding game                                        | string    |
# | color                              | team color (blue/orange)                                        | string    |
# | team_id                            | id of corresponding team                                        | string    |
# | team_slug                          | team URL slug                                                   | string    |
# | team_name                          | name of team                                                    | string    |
# | team_region                        | team region                                                     | string    |
# | ball_possession_time               | time team had ball possession                                   | float     |
# | ball_time_in_side                  | time ball was in team's side                                    | float     |
# | core_shots                         | shots                                                           | int       |
# | core_goals                         | goals                                                           | int       |
# | core_saves                         | saves                                                           | int       |
# | core_assists                       | assists                                                         | int       |
# | core_score                         | score                                                           | int       |
# | core_shooting_percentage           | shooting percentage                                             | float     |
# | boost_bpm                          | boost used per minute                                           | float     |
# | boost_bcpm                         | boost collected per minute                                      | float     |
# | boost_avg_amount                   | average boost amount in tank                                    | float     |
# | boost_amount_collected             | total boost collected                                           | float     |
# | boost_amount_stolen                | total boost stolen from opponent half                           | float     |
# | boost_amount_collected_big         | total boost collected from big pads                             | float     |
# | boost_amount_stolen_big            | total boost collected from big pads stolen from opponent half   | float     |
# | boost_amount_collected_small       | total boost collected from small pads                           | float     |
# | boost_amount_stolen_small          | total boost collected from small pads stolen from opponent half | float     |
# | boost_count_collected_big          | count of big pads collected                                     | int       |
# | boost_count_stolen_big             | count of big pads stolen                                        | int       |
# | boost_count_collected_small        | count of small pads collected                                   | int       |
# | boost_count_stolen_small           | count of small pads stolen                                      | int       |
# | boost_amount_overfill              | overfill boost amount                                           | float     |
# | boost_amount_overfill_stolen       | stolen overfill boost amount                                    | float     |
# | boost_amount_used_while_supersonic | total boost amount used while supersonic speed                  | float     |
# | boost_time_zero_boost              | time zero boost                                                 | float     |
# | boost_time_full_boost              | time full boost                                                 | float     |
# | boost_time_boost_0_25              | time boost 0 - 25                                               | float     |
# | boost_time_boost_25_50             | time boost 25 - 50                                              | float     |
# | boost_time_boost_50_75             | time boost 50 - 75                                              | float     |
# | boost_time_boost_75_100            | time boost 75 - 100                                             | float     |
# | movement_total_distance            | total distance                                                  | float     |
# | movement_time_supersonic_speed     | time supersonic speed                                           | float     |
# | movement_time_boost_speed          | time boost speed                                                | float     |
# | movement_time_slow_speed           | time slow speed                                                 | float     |
# | movement_time_ground               | time on ground                                                  | float     |
# | movement_time_low_air              | time in low air                                                 | float     |
# | movement_time_high_air             | time in high air                                                | float     |
# | movement_time_powerslide           | time powersliding                                               | float     |
# | movement_count_powerslide          | powerslide count                                                | int       |
# | positioning_time_defensive_third   | time in defensive third                                         | float     |
# | positioning_time_neutral_third     | time in neutral third                                           | float     |
# | positioning_time_offensive_third   | time in offensive third                                         | float     |
# | positioning_time_defensive_half    | time in defensive half                                          | float     |
# | positioning_time_offensive_half    | time in offensive half                                          | float     |
# | positioning_time_behind_ball       | time behind the ball                                            | float     |
# | positioning_time_in_front_ball     | time in front of the ball                                       | float     |
# | demo_inflicted                     | demos inflicted                                                 | int       |
# | demo_taken                         | demos taken                                                     | int       |
# | winner                             | won game                                                        | bool      |
#
# main:
#
# | Field                 | Description                         | Data Type |
# | --------------------- | ----------------------------------- | --------- |
# | event_id              | id of corresponding event           | string    |
# | event                 | name of event                       | string    |
# | event_split           | event split (Fall/Winter/Spring)    | string    |
# | event_region          | event region                        | string    |
# | event_slug            | event URL slug                      | string    |
# | event_start_date      | event start date                    | datetime  |
# | event_end_date        | event end date                      | datetime  |
# | event_tier            | event tier (Qualifier/Major/etc)    | string    |
# | event_phase           | event phase                         | string    |
# | prize_money           | prize money for event               | float     |
# | stage_step            | stage step number                   | int       |
# | stage                 | stage name                          | string    |
# | stage_start_date      | stage start date                    | datetime  |
# | stage_end_date        | stage end date                      | datetime  |
# | stage_is_lan          | whether stage is LAN event          | bool      |
# | stage_is_qualifier    | whether stage is qualifier          | bool      |
# | liquipedia_link       | link to Liquipedia page             | string    |
# | location_venue        | venue location                      | string    |
# | location_city         | city location                       | string    |
# | location_country      | country location                    | string    |
# | match_id              | id of corresponding match           | string    |
# | match_slug            | match URL slug                      | string    |
# | match_number          | match number                        | int       |
# | match_round           | match round                         | string    |
# | match_date            | match date                          | datetime  |
# | match_format          | match format (best-of-X)            | string    |
# | reverse_sweep_attempt | whether reverse sweep was attempted | bool      |
# | reverse_sweep         | whether reverse sweep occurred      | bool      |
# | game_id               | id of corresponding game            | string    |
# | game_number           | game number within match            | float     |
# | game_date             | game date                           | datetime  |
# | game_duration         | game duration in seconds            | float     |
# | map_id                | id of map                           | string    |
# | map_name              | name of map                         | string    |
# | overtime              | whether game went to overtime       | bool      |
# | ballchasing_id        | ballchasing replay id               | string    |
#
# matches_by_players:
#
# | Field                                          | Description                                                     | Data Type |
# | ---------------------------------------------- | --------------------------------------------------------------- | --------- |
# | match_id                                       | id of corresponding match                                       | string    |
# | team_id                                        | id of corresponding team                                        | string    |
# | team_region                                    | team region                                                     | string    |
# | player_id                                      | id of corresponding player                                      | string    |
# | player_tag                                     | name of player                                                  | string    |
# | core_shots                                     | shots                                                           | float     |
# | core_goals                                     | goals                                                           | float     |
# | core_saves                                     | saves                                                           | float     |
# | core_assists                                   | assists                                                         | float     |
# | core_score                                     | score                                                           | float     |
# | core_shooting_percentage                       | shooting percentage                                             | float     |
# | boost_bpm                                      | boost used per minute                                           | float     |
# | boost_bcpm                                     | boost collected per minute                                      | float     |
# | boost_avg_amount                               | average boost amount in tank                                    | float     |
# | boost_amount_collected                         | total boost collected                                           | float     |
# | boost_amount_stolen                            | total boost stolen from opponent half                           | float     |
# | boost_amount_collected_big                     | total boost collected from big pads                             | float     |
# | boost_amount_stolen_big                        | total boost collected from big pads stolen from opponent half   | float     |
# | boost_amount_collected_small                   | total boost collected from small pads                           | float     |
# | boost_amount_stolen_small                      | total boost collected from small pads stolen from opponent half | float     |
# | boost_count_collected_big                      | count of big pads collected                                     | float     |
# | boost_count_stolen_big                         | count of big pads stolen                                        | float     |
# | boost_count_collected_small                    | count of small pads collected                                   | float     |
# | boost_count_stolen_small                       | count of small pads stolen                                      | float     |
# | boost_amount_overfill                          | overfill boost amount                                           | float     |
# | boost_amount_overfill_stolen                   | stolen overfill boost amount                                    | float     |
# | boost_amount_used_while_supersonic             | total boost amount used while supersonic speed                  | float     |
# | boost_time_zero_boost                          | time zero boost                                                 | float     |
# | boost_percent_zero_boost                       | percent of match with zero boost                                | float     |
# | boost_time_full_boost                          | time full boost                                                 | float     |
# | boost_percent_full_boost                       | percent of match with full boost                                | float     |
# | boost_time_boost_0_25                          | time boost 0 - 25                                               | float     |
# | boost_time_boost_25_50                         | time boost 25 - 50                                              | float     |
# | boost_time_boost_50_75                         | time boost 50 - 75                                              | float     |
# | boost_time_boost_75_100                        | time boost 75 - 100                                             | float     |
# | boost_percent_boost_0_25                       | percent of match with boost 0 - 25                              | float     |
# | boost_percent_boost_25_50                      | percent of match with boost 25 - 50                             | float     |
# | boost_percent_boost_50_75                      | percent of match with boost 50 - 75                             | float     |
# | boost_percent_boost_75_100                     | percent of match with boost 75 - 100                            | float     |
# | movement_avg_speed                             | average speed (unreal units)                                    | float     |
# | movement_total_distance                        | total distance                                                  | float     |
# | movement_time_supersonic_speed                 | time supersonic speed                                           | float     |
# | movement_time_boost_speed                      | time boost speed                                                | float     |
# | movement_time_slow_speed                       | time slow speed                                                 | float     |
# | movement_time_ground                           | time on ground                                                  | float     |
# | movement_time_low_air                          | time in low air                                                 | float     |
# | movement_time_high_air                         | time in high air                                                | float     |
# | movement_time_powerslide                       | time powersliding                                               | float     |
# | movement_count_powerslide                      | powerslide count                                                | float     |
# | movement_avg_powerslide_duration               | average powerslide duration                                     | float     |
# | movement_avg_speed_percentage                  | average speed percentage                                        | float     |
# | movement_percent_slow_speed                    | percent of match slow speed                                     | float     |
# | movement_percent_boost_speed                   | percent of match boost speed                                    | float     |
# | movement_percent_supersonic_speed              | percent of match supersonic speed                               | float     |
# | movement_percent_ground                        | percent of match on ground                                      | float     |
# | movement_percent_low_air                       | percent of match in low air                                     | float     |
# | movement_percent_high_air                      | percent of match in high air                                    | float     |
# | positioning_avg_distance_to_ball               | average distance to ball                                        | float     |
# | positioning_avg_distance_to_ball_possession    | average distance to ball with possession                        | float     |
# | positioning_avg_distance_to_ball_no_possession | average distance to ball with no possession                     | float     |
# | positioning_avg_distance_to_mates              | average distance to teammates                                   | float     |
# | positioning_time_defensive_third               | time in defensive third                                         | float     |
# | positioning_time_neutral_third                 | time in neutral third                                           | float     |
# | positioning_time_offensive_third               | time in offensive third                                         | float     |
# | positioning_time_defensive_half                | time in defensive half                                          | float     |
# | positioning_time_offensive_half                | time in offensive half                                          | float     |
# | positioning_time_behind_ball                   | time behind the ball                                            | float     |
# | positioning_time_in_front_ball                 | time in front of the ball                                       | float     |
# | positioning_time_most_back                     | time most back on team                                          | float     |
# | positioning_time_most_forward                  | time most forward on team                                       | float     |
# | positioning_goals_against_while_last_defender  | goals against while last defender                               | float     |
# | positioning_time_closest_to_ball               | time closest to ball                                            | float     |
# | positioning_time_farthest_from_ball            | time farthest from ball                                         | float     |
# | positioning_percent_defensive_third            | percent of match in defensive third                             | float     |
# | positioning_percent_offensive_third            | percent of match in offensive third                             | float     |
# | positioning_percent_neutral_third              | percent of match in neutral third                               | float     |
# | positioning_percent_defensive_half             | percent of match in defensive half                              | float     |
# | positioning_percent_offensive_half             | percent of match in offensive half                              | float     |
# | positioning_percent_behind_ball                | percent of match behind the ball                                | float     |
# | positioning_percent_in_front_ball              | percent of match in front of the ball                           | float     |
# | positioning_percent_most_back                  | percent of match most back                                      | float     |
# | positioning_percent_most_forward               | percent of match most forward                                   | float     |
# | positioning_percent_closest_to_ball            | percent of match closest to the ball                            | float     |
# | positioning_percent_farthest_from_ball         | percent of match farthest from the ball                         | float     |
# | demo_inflicted                                 | demos inflicted                                                 | float     |
# | demo_taken                                     | demos taken                                                     | float     |
# | advanced_goal_participation                    | goal participation                                              | float     |
# | advanced_rating                                | average rating                                                  | float     |
# | score                                          | match score (games won)                                         | float     |
# | winner                                         | won match                                                       | bool      |
#
# matches_by_teams:
#
# | Field                              | Description                                                     | Data Type |
# | ---------------------------------- | --------------------------------------------------------------- | --------- |
# | match_id                           | id of corresponding match                                       | string    |
# | color                              | team color (blue/orange)                                        | string    |
# | team_id                            | id of corresponding team                                        | string    |
# | team_slug                          | team URL slug                                                   | string    |
# | team_name                          | name of team                                                    | string    |
# | team_region                        | team region                                                     | string    |
# | core_shots                         | shots                                                           | int       |
# | core_goals                         | goals                                                           | int       |
# | core_saves                         | saves                                                           | int       |
# | core_assists                       | assists                                                         | int       |
# | core_score                         | score                                                           | int       |
# | core_shooting_percentage           | shooting percentage                                             | float     |
# | boost_bpm                          | boost used per minute                                           | float     |
# | boost_bcpm                         | boost collected per minute                                      | float     |
# | boost_avg_amount                   | average boost amount in tank                                    | float     |
# | boost_amount_collected             | total boost collected                                           | float     |
# | boost_amount_stolen                | total boost stolen from opponent half                           | float     |
# | boost_amount_collected_big         | total boost collected from big pads                             | float     |
# | boost_amount_stolen_big            | total boost collected from big pads stolen from opponent half   | float     |
# | boost_amount_collected_small       | total boost collected from small pads                           | float     |
# | boost_amount_stolen_small          | total boost collected from small pads stolen from opponent half | float     |
# | boost_count_collected_big          | count of big pads collected                                     | int       |
# | boost_count_stolen_big             | count of big pads stolen                                        | int       |
# | boost_count_collected_small        | count of small pads collected                                   | int       |
# | boost_count_stolen_small           | count of small pads stolen                                      | int       |
# | boost_amount_overfill              | overfill boost amount                                           | float     |
# | boost_amount_overfill_stolen       | stolen overfill boost amount                                    | float     |
# | boost_amount_used_while_supersonic | total boost amount used while supersonic speed                  | float     |
# | boost_time_zero_boost              | time zero boost                                                 | float     |
# | boost_time_full_boost              | time full boost                                                 | float     |
# | boost_time_boost_0_25              | time boost 0 - 25                                               | float     |
# | boost_time_boost_25_50             | time boost 25 - 50                                              | float     |
# | boost_time_boost_50_75             | time boost 50 - 75                                              | float     |
# | boost_time_boost_75_100            | time boost 75 - 100                                             | float     |
# | movement_total_distance            | total distance                                                  | float     |
# | movement_time_supersonic_speed     | time supersonic speed                                           | float     |
# | movement_time_boost_speed          | time boost speed                                                | float     |
# | movement_time_slow_speed           | time slow speed                                                 | float     |
# | movement_time_ground               | time on ground                                                  | float     |
# | movement_time_low_air              | time in low air                                                 | float     |
# | movement_time_high_air             | time in high air                                                | float     |
# | movement_time_powerslide           | time powersliding                                               | float     |
# | movement_count_powerslide          | powerslide count                                                | int       |
# | positioning_time_defensive_third   | time in defensive third                                         | float     |
# | positioning_time_neutral_third     | time in neutral third                                           | float     |
# | positioning_time_offensive_third   | time in offensive third                                         | float     |
# | positioning_time_defensive_half    | time in defensive half                                          | float     |
# | positioning_time_offensive_half    | time in offensive half                                          | float     |
# | positioning_time_behind_ball       | time behind the ball                                            | float     |
# | positioning_time_in_front_ball     | time in front of the ball                                       | float     |
# | demo_inflicted                     | demos inflicted                                                 | int       |
# | demo_taken                         | demos taken                                                     | int       |
# | score                              | match score (games won)                                         | float     |
# | winner                             | won match                                                       | bool      |
#
# players_db:
#
# | Field          | Description                | Data Type |
# | -------------- | -------------------------- | --------- |
# | player_id      | id of corresponding player | string    |
# | player_slug    | player URL slug            | string    |
# | player_tag     | player tag/username        | string    |
# | player_name    | player real name           | string    |
# | player_country | player country code        | string    |
#
# > - License: https://creativecommons.org/publicdomain/zero/1.0/
#
# ### Data set selection rationale
#
# > Why did you select this data set?
#
# I chose this dataset because I enjoy watching competitive Rocket League and wanted to see what I could find out from a dataset I could find.
#
# ### Questions to be answered
#
# > Using statistical analysis and visualization, what questions would you like to be able answer about this dataset.
# > This could include questions such as:
# >
# > - What is the relationship between X and Y variables?
# > - What is the distribution of the variables?
# > - What is the relationship between the variables and the target?
# >   You will need to frame these questions in a way to show value to a stakeholder (i.e.why should we know about the relationship between X and Y variables?)
#
# - What factors most strongly influence a team's chances of winning?
#   For example, is boost usage, average speed, or time spent in various field zones correlated with match outcomes? Understanding these can help teams optimize their strategies.
#
# - How do individual player stats (e.g., shots, goals, saves) distribute across the league?
#   Knowing the typical range and distribution of these key performance indicators can help benchmark player performance and set realistic training targets.
#
# - Are there notable differences in play style or performance between regions or teams?
#   Comparing metrics like average boost usage or defensive time by region can highlight competitive advantages and inform transfer or recruitment strategies.
#
# - What player or team characteristics are associated with high goal participation or MVP status?
#   Identifying these characteristics could help in talent scouting or developing players for key roles.
#
# - Is there a relationship between match duration, overtime frequency, and total goals scored or player fatigue indicators?
#   This could provide insights for scheduling and managing player workload.
#
# Answering these questions will add practical value by helping stakeholders understand which in-game behaviors and stats drive successful outcomes and where to focus training or scouting efforts.
#
# ### Visualization ideas
#
# > Provide a few examples of what you plan to visualize to answer the questions you posed in the previous section. In this project, you will be producing 6-8 visualizations. You will also be producing an interactive chart using Plotly.
# > Think about what those visualization could be: what are the variables used in the charts? what insights do you hope to gain from them?
#
# Example Visualizations Planned:
#
# 1.  Distribution of Core Player Stats:
#
#     - Visualization: Histograms or boxplots of shots, goals, and saves per player.
#     - Variables: core_shots, core_goals, core_saves (from matches_by_players).
#     - Insight: Identify typical performance ranges and spot outliers or standout performers.
#
# 2.  Correlation Heatmap of Team Metrics and Winning:
#
#     - Visualization: Correlation matrix heatmap.
#     - Variables: Various team-level stats (e.g., boost_avg_amount, core_shots, movement_avg_speed, positioning_time_offensive_third) plus winner (from matches_by_teams).
#     - Insight: See which features most strongly correlate with winning to help teams focus training efforts.
#
# 3.  Regional Comparison of Play Styles:
#
#     - Visualization: Grouped bar chart comparing average boost usage and time in field zones by region.
#     - Variables: team_region, boost_bpm, movement_time_supersonic_speed, positioning_time_offensive_third (from matches_by_teams).
#     - Insight: Discover stylistic differences between regions that might indicate unique strategies.
#
# 4.  Goal Participation by Player Position and Role:
#
#     - Visualization: Strip plot or violin plot of goal participation versus average positioning.
#     - Variables: advanced_goal_participation, positioning_avg_distance_to_ball, positioning_time_most_forward (from matches_by_players).
#     - Insight: Analyze if certain player roles are more involved in goals.
#
# 5.  Relationship Between Match Duration, Overtime, and Total Goals:
#
#     - Visualization: Scatter plot with regression line.
#     - Variables: match duration, overtime frequency, total goals (aggregated from matches_by_teams).
#     - Insight: Determine if longer or overtime-heavy matches have more goals, which can affect player fatigue.
#
# 6.  Interactive Plotly Dashboard:
#     - Visualization: Interactive filterable chart (e.g., team or player stat comparison across regions or over time).
#     - Variables: User-selectable, but could include goals, assists, saves, or advanced_rating (from matches_by_players and teams, joined with region info).
#     - Insight: Allow stakeholders to explore comparisons tailored to their interests.
#
# These visualizations are designed to extract actionable insights regarding player performance, team strategies, regional trends, and key drivers for match outcomes.

# %% [markdown]
# ## Data Loading and File I/O
#
# This section implements robust file reading with proper exception handling.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from pathlib import Path
import plotly.graph_objects as go
import plotly.express as px

# %%
def load_csv(path: Path, **kwargs):
  try:
    df = pd.read_csv(path, **kwargs)
  except FileNotFoundError as e:
    raise FileNotFoundError(
        f"Could not find {path.name}. Check data/ folder and filename."
    ) from e
  except pd.errors.ParserError as e:
    raise ValueError(
        f"Parsing failed for {path.name}. Check delimiter or bad rows."
    ) from e
  else:
    return df


data_dir = Path("data")

try:
  main = load_csv(data_dir / "main.csv")
  players = load_csv(data_dir / "players_db.csv")
  games_players = load_csv(data_dir / "games_by_players.csv", low_memory=False)
  games_teams = load_csv(data_dir / "games_by_teams.csv")
  matches_players = load_csv(data_dir / "matches_by_players.csv")
  matches_teams = load_csv(data_dir / "matches_by_teams.csv")
  print("All datasets loaded successfully!")
except (FileNotFoundError, ValueError) as e:
  print(f"Error loading data: {e}")
# Out:
# All datasets loaded successfully!

# %% [markdown]
# ## Data Preparation and Cleaning
#
# This section prepares the data for analysis using Python data structures and pandas operations.

# %%
# Convert date columns to datetime
main['match_date'] = pd.to_datetime(main['match_date'])
main['game_date'] = pd.to_datetime(main['game_date'])
main['event_start_date'] = pd.to_datetime(main['event_start_date'])

# Set categorical order for regions (using set to get unique values, then dict to map order)
unique_regions: set = set(matches_teams['team_region'].dropna())
region_order: list = sorted(list(unique_regions))  # Alphabetical order
region_cat_map: dict = {region: idx for idx, region in enumerate(region_order)}

# Convert to categorical with intentional order
matches_teams['team_region'] = pd.Categorical(
    matches_teams['team_region'],
    categories=region_order,
    ordered=True
)
matches_players['team_region'] = pd.Categorical(
    matches_players['team_region'],
    categories=region_order,
    ordered=True
)

# Create a tuple of key performance metrics for analysis
key_metrics: tuple = (
    'core_goals', 'core_shots', 'core_saves', 'core_assists',
    'boost_bpm', 'movement_avg_speed', 'advanced_rating'
)

print(
    f"Data prepared. Analyzing {len(key_metrics)} key metrics across regions.")

# Merge match data with main to get dates and event info
matches_teams_enriched = matches_teams.merge(
    main[['match_id', 'match_date', 'event_region', 'event_split']].drop_duplicates(),
    on='match_id',
    how='left'
)

# Merge player match data with player database
matches_players_enriched = matches_players.merge(
    players[['player_id', 'player_tag', 'player_country']],
    on='player_id',
    how='left',
    suffixes=('', '_db')
)

# Use the tag from database if available, otherwise use the one from matches
matches_players_enriched['player_tag'] = matches_players_enriched['player_tag_db'].fillna(
    matches_players_enriched['player_tag']
)

print(
    f"Merged datasets: {matches_teams_enriched.shape[0]} team matches, {matches_players_enriched.shape[0]} player matches")

# Groupby with aggregation: Average team stats by region
team_stats_by_region = matches_teams_enriched.groupby('team_region', observed=True).agg({
    'core_goals': ['mean', 'std'],
    'core_shots': ['mean', 'std'],
    'core_saves': ['mean', 'std'],
    'boost_bpm': ['mean', 'std'],
    'movement_total_distance': ['mean', 'std'],
    'winner': 'mean'
}).round(2)

team_stats_by_region.columns = [
    '_'.join(col).strip() for col in team_stats_by_region.columns.values]
print("Team statistics by region:")
print(team_stats_by_region)

# Tidy reshape: Pivot table for player performance by region
player_perf_pivot = matches_players_enriched.pivot_table(
    values=['core_goals', 'core_saves', 'advanced_rating'],
    index='team_region',
    aggfunc='mean',
    observed=True
).round(2)

print("Player performance pivot table by region:")
print(player_perf_pivot)
# Out:
# Data prepared. Analyzing 7 key metrics across regions.
# Merged datasets: 10594 team matches, 26176 player matches
# Team statistics by region:
#                             core_goals_mean  core_goals_std  core_shots_mean  \
# team_region
# Asia-Pacific North                     8.84            4.72            29.81
# Asia-Pacific South                     9.28            4.56            30.14
# Europe                                 8.11            3.62            35.86
# Middle East & North Africa             8.72            4.05            33.37
# North America                          7.99            3.50            34.91
# Oceania                                8.48            3.95            32.46
# South America                          8.44            3.95            33.49
# Sub-Saharan Africa                     9.63            4.96            31.41
#
#                             core_shots_std  core_saves_mean  core_saves_std  \
# team_region
# ...

# %% [markdown]
# ## Visualizations
#
# This section creates 6-8 visualizations including distribution plots, comparisons, relationships, time series, multi-panel figures, and an interactive Plotly chart.

# %% [markdown]
# ### Visualization 1: Distribution plot - Goals per player
#
# This plot shows the distribution and summary stats of goals scored per player per match using a histogram.

# %%
# Set style
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

# Visualization 1: Distribution plot - Goals per player (histogram only)
fig, ax = plt.subplots(figsize=(10, 6))
player_goals = matches_players_enriched['core_goals'].dropna()

max_goals = int(player_goals.max())
bins = [x - 0.5 for x in range(max_goals + 2)]

# Histogram with counts (not density) - shows actual number of players
ax.hist(player_goals, bins=bins, density=False, alpha=0.7,
        color='steelblue', edgecolor='black')

ax.set_xlabel('Goals per Match', fontsize=12)
ax.set_ylabel('Frequency (Count)', fontsize=12)
ax.set_title('Distribution of Goals per Player per Match',
             fontsize=14, fontweight='bold')
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Summary statistics
print(f"\nGoals Distribution Summary:")
print(f"Mean: {player_goals.mean():.2f}")
print(f"Median: {player_goals.median():.2f}")
print(f"Std: {player_goals.std():.2f}")
print(f"Skew: {player_goals.skew():.2f}")
print(f"Min: {player_goals.min():.2f}, Max: {player_goals.max():.2f}")
# Out:
# Goals Distribution Summary:
# Mean: 2.86
# Median: 3.00
# Std: 2.00
# Skew: 0.77
# Min: 0.00, Max: 15.00

# %% [markdown]
# ### Visualization 2: Comparison plot - Box plot of boost usage by region
#
# Box plot comparing boost per minute (boost_bpm) by region.

# %%
# Visualization 2: Comparison plot - Box plot of boost usage by region
fig, ax = plt.subplots(figsize=(12, 6))

# Filter out any rows with missing data for region or boost_bpm
data_for_box = matches_teams_enriched.dropna(
    subset=['team_region', 'boost_bpm'])

sns.boxplot(
    data=data_for_box,
    x='team_region',
    y='boost_bpm',
    hue='team_region',
    legend=False,
    ax=ax,
    palette='Set2'
)

# Remove duplicate region labels from the legend if present
handles, labels = ax.get_legend_handles_labels()
if len(handles) > 0:
  ax.get_legend().remove()

ax.set_xlabel('Region', fontsize=12)
ax.set_ylabel('Boost Used per Minute', fontsize=12)
ax.set_title('Boost Usage Comparison Across Regions',
             fontsize=14, fontweight='bold')
ax.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Visualization 3: Relationship plot - Scatter with fitted line
#
# Scatter plot with fitted line showing relationship between shots and goals

# %%
# Visualization 3: Relationship plot - Scatter with fitted line
fig, ax = plt.subplots(figsize=(10, 6))

# Sample for performance if dataset is large
sample_data = matches_teams_enriched[['core_goals', 'core_shots']].dropna()
if len(sample_data) > 10000:
  sample_data = sample_data.sample(n=10000, random_state=42)

ax.scatter(sample_data['core_shots'], sample_data['core_goals'],
           alpha=0.5, s=20, color='steelblue')

# Fit regression line
slope, intercept, r_value, p_value, std_err = stats.linregress(
    sample_data['core_shots'],
    sample_data['core_goals']
)
line_x = np.linspace(
    sample_data['core_shots'].min(), sample_data['core_shots'].max(), 100)
line_y = slope * line_x + intercept
ax.plot(line_x, line_y, 'r--', linewidth=2, label=f'R² = {r_value**2:.3f}')

ax.set_xlabel('Shots', fontsize=12)
ax.set_ylabel('Goals', fontsize=12)
ax.set_title('Relationship Between Shots and Goals (with Regression Line)',
             fontsize=14, fontweight='bold')
ax.legend()
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"Correlation coefficient (r): {r_value:.3f}")
print(f"R-squared: {r_value**2:.3f}")
# Out:
# Correlation coefficient (r): 0.671
# R-squared: 0.451

# %% [markdown]
# # Visualization 4: Time series - Average goals per match over time
#
# Time series to show average goals per match throughout the year grouped by month.

# %%
# Visualization 4: Time series - Average goals per match over time
matches_teams_enriched['match_date'] = pd.to_datetime(
    matches_teams_enriched['match_date'])
time_series_data = matches_teams_enriched.groupby(
    matches_teams_enriched['match_date'].dt.to_period('M')
)['core_goals'].mean().reset_index()
# Mark month as string for labeling
time_series_data['match_date'] = time_series_data['match_date'].astype(str)

fig, ax = plt.subplots(figsize=(14, 6))
ax.plot(time_series_data['match_date'], time_series_data['core_goals'],
        marker='o', linewidth=2, markersize=6, color='steelblue')

ax.set_xlabel('Month', fontsize=12)
ax.set_ylabel('Average Goals per Match', fontsize=12)
ax.set_title('Time Series: Average Goals per Match Over Time',
             fontsize=14, fontweight='bold')

# Set x-ticks to months directly (avoid using integer index)
ax.set_xticks(range(len(time_series_data)))
ax.set_xticklabels(time_series_data['match_date'], rotation=45, ha='right')
# Start y-axis at 0
ax.set_ylim(bottom=0)
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Visualization 5: Multi-panel figure - Feceted comparison
#
# 4 Box charts with different stats grouped by region.

# %%
# Visualization 5: Multi-panel figure - Faceted comparison
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
fig.suptitle('Multi-Panel Analysis: Team Performance Metrics',
             fontsize=16, fontweight='bold')

# Panel 1: Goals by region
data_for_viz = matches_teams_enriched.dropna(
    subset=['team_region', 'core_goals'])
sns.boxplot(data=data_for_viz, x='team_region',
            y='core_goals', hue='team_region', legend=False, ax=axes[0, 0], palette='Set2')
axes[0, 0].set_title('Goals Distribution by Region')
axes[0, 0].tick_params(axis='x', rotation=45)
axes[0, 0].legend_.remove() if axes[0, 0].get_legend() else None

# Panel 2: Saves by region
sns.boxplot(data=data_for_viz, x='team_region',
            y='core_saves', hue='team_region', legend=False, ax=axes[0, 1], palette='Set2')
axes[0, 1].set_title('Saves Distribution by Region')
axes[0, 1].tick_params(axis='x', rotation=45)
axes[0, 1].legend_.remove() if axes[0, 1].get_legend() else None

# Panel 3: Boost usage by region
sns.boxplot(data=data_for_viz, x='team_region',
            y='boost_bpm', hue='team_region', legend=False, ax=axes[1, 0], palette='Set2')
axes[1, 0].set_title('Boost Usage by Region')
axes[1, 0].tick_params(axis='x', rotation=45)
axes[1, 0].legend_.remove() if axes[1, 0].get_legend() else None

# Panel 4: Assists by region (replace win rate)
sns.boxplot(data=data_for_viz, x='team_region',
            y='core_assists', hue='team_region', legend=False, ax=axes[1, 1], palette='Set2')
axes[1, 1].set_title('Assists Distribution by Region')
axes[1, 1].set_ylabel('Assists')
axes[1, 1].tick_params(axis='x', rotation=45)
axes[1, 1].legend_.remove() if axes[1, 1].get_legend() else None

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Visualization 6: Correlation heatmap
#
# Heatmap that shows the correlation between properties.

# %%
# Visualization 6: Correlation heatmap
# Select numeric columns for correlation
numeric_cols = ['core_goals', 'core_shots', 'core_saves', 'core_assists',
                'boost_bpm', 'boost_bcpm', 'movement_total_distance',
                'positioning_time_offensive_third', 'winner']

corr_data = matches_teams_enriched[numeric_cols].corr()

fig = go.Figure(data=go.Heatmap(
    z=corr_data.values,
    x=corr_data.columns,
    y=corr_data.columns,
    colorscale='RdBu',
    zmid=0,
    text=corr_data.values.round(2),
    texttemplate='%{text}',
    textfont={"size": 10},
    colorbar=dict(title="Correlation")
))

fig.update_layout(
    title='Correlation Heatmap: Team Performance Metrics',
    width=800,
    height=700
)

fig.show()

# %% [markdown]
# ### Visualization 7: Interactive Plotly - Player performance by region
#
# Interactive scatter plot of players with goals per match and saves per match and highlighted by region with colors.

# %%
# Visualization 7: Interactive Plotly - Player performance by region
# Create aggregated data for interactive visualization
player_perf_interactive = matches_players_enriched.groupby(
    ['team_region', 'player_tag'], observed=True
).agg({
    'core_goals': 'mean',
    'core_saves': 'mean',
    'advanced_rating': 'mean'
}).reset_index()

# Filter to top players by rating for better visualization
top_players = player_perf_interactive.nlargest(100, 'advanced_rating')

fig = px.scatter(
    top_players,
    x='core_goals',
    y='core_saves',
    size='advanced_rating',
    color='team_region',
    hover_data=['player_tag'],
    title='Player Performance by Region (Top 100 by Rating)',
    labels={
        'core_goals': 'Average Goals per Match',
        'core_saves': 'Average Saves per Match',
        'advanced_rating': 'Average Rating',
        'team_region': 'Region'
    },
    width=900,
    height=600
)

fig.update_traces(marker=dict(line=dict(width=1, color='DarkSlateGrey')))
fig.update_layout(legend=dict(
    orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1))
fig.show()
